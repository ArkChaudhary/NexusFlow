# %% [markdown]
# NexusFlow: Complete Tutorial & Demo
# Multi-Transformer Framework for Tabular Ecosystems

# %%
"""
This notebook provides a comprehensive walkthrough of NexusFlow, demonstrating:
1. Project initialization and setup
2. Data preparation and configuration
3. Model training with both synthetic and real data
4. Model evaluation and inference
5. Advanced features and introspection

NexusFlow is inspired by AlphaFold 2's collaborative intelligence approach,
using multiple specialized transformers that communicate via cross-attention.
"""
# Out:
# "\nThis notebook provides a comprehensive walkthrough of NexusFlow, demonstrating:\n1. Project initialization and setup\n2. Data preparation and configuration\n3. Model training with both synthetic and real data\n4. Model evaluation and inference\n5. Advanced features and introspection\n\nNexusFlow is inspired by AlphaFold 2's collaborative intelligence approach,\nusing multiple specialized transformers that communicate via cross-attention.\n"

# %%
import sys
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, Markdown
import warnings
warnings.filterwarnings('ignore')

# %%
# Setup styling
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
print("🔗 NexusFlow - Multi-Transformer Framework for Tabular Data")
print("=" * 60)
# Out:
# 🔗 NexusFlow - Multi-Transformer Framework for Tabular Data
# ============================================================

# %% [markdown]
# # 🚀 Section 1: Environment Setup & Installation

# %%
# First, let's verify our NexusFlow installation and setup
try:
    # Add the src directory to path if running from project root
    if 'src' not in sys.path:
        src_path = Path.cwd() / 'src'
        if src_path.exists():
            sys.path.insert(0, str(src_path))
        else:
            print("⚠️  Running from non-project directory. Ensure nexusflow is installed.")
    
    # Import core NexusFlow modules
    from src.nexusflow import __version__
    from src.nexusflow.config import load_config_from_file, ConfigModel
    from src.nexusflow.project_manager import ProjectManager
    from src.nexusflow.trainer.trainer import Trainer
    from src.nexusflow.api.model_api import load_model, ModelAPI
    from src.nexusflow.data.ingestion import load_datasets, align_datasets
    
    print(f"✅ NexusFlow v{__version__} loaded successfully!")
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("💡 Make sure you're running from the project root or have installed nexusflow")
    print("   Try: pip install -e .")
# Out:
# ✅ NexusFlow v0.1.0 loaded successfully!

# %% [markdown]
# # 🏗️ Section 2: Project Initialization

# %%
def demo_project_initialization():
    """Demonstrate NexusFlow project structure creation."""
    print("\n" + "="*60)
    print("🏗️  PROJECT INITIALIZATION DEMO")
    print("="*60)
    
    # Initialize project manager
    pm = ProjectManager()
    
    # Create a demo project (use force to overwrite if exists)
    project_name = "nexusflow_demo"
    
    try:
        project_path = pm.init_project(project_name, force=True)
        print(f"✅ Demo project created at: {project_path}")
        
        # Show the created directory structure
        demo_path = Path(project_name)
        if demo_path.exists():
            print("\n📁 Project Structure:")
            for item in sorted(demo_path.rglob("*")):
                if item.is_dir():
                    level = len(item.relative_to(demo_path).parts)
                    indent = "  " * (level - 1)
                    print(f"{indent}📁 {item.name}/")
                elif item.name.endswith(('.yaml', '.yml', '.md', '.txt')):
                    level = len(item.relative_to(demo_path).parts)
                    indent = "  " * (level - 1)
                    print(f"{indent}📄 {item.name}")
        
        return demo_path
    except Exception as e:
        print(f"❌ Project creation failed: {e}")
        return None

# %%
# Run the demo
demo_project = demo_project_initialization()
# Out:
# 2025-08-25 03:29:32.172 | DEBUG    | src.nexusflow.project_manager:init_project:32 - Directory created: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo\configs
# 2025-08-25 03:29:32.175 | DEBUG    | src.nexusflow.project_manager:init_project:32 - Directory created: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo\datasets
# 2025-08-25 03:29:32.181 | DEBUG    | src.nexusflow.project_manager:init_project:32 - Directory created: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo\models
# 2025-08-25 03:29:32.187 | DEBUG    | src.nexusflow.project_manager:init_project:32 - Directory created: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo\notebooks
# 2025-08-25 03:29:32.193 | DEBUG    | src.nexusflow.project_manager:init_project:32 - Directory created: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo\results
# 2025-08-25 03:29:32.196 | DEBUG    | src.nexusflow.project_manager:init_project:32 - Directory created: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo\src
# 2025-08-25 03:29:32.199 | INFO     | src.nexusflow.project_manager:init_project:34 - Project initialized at: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo
# ============================================================
# 🏗️  PROJECT INITIALIZATION DEMO
# ============================================================
# ✅ Demo project created at: C:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\nexusflow_demo
#
# 📁 Project Structure:
# 📁 configs/
# 📁 datasets/
# 📁 models/
# 📁 notebooks/
# 📁 results/
# 📁 src/

# %% [markdown]
# # 📊 Section 3: Synthetic Data Training Demo

# %%
def run_synthetic_training_demo():
    """Demonstrate training with synthetic data."""
    print("\n" + "="*60)
    print("📊 SYNTHETIC DATA TRAINING DEMO")
    print("="*60)
    
    # Create a synthetic data configuration
    synthetic_config = {
        'project_name': 'synthetic_demo',
        'primary_key': 'id',
        'target': {
            'target_table': 'table_a.csv',
            'target_column': 'label'
        },
        'architecture': {
            'refinement_iterations': 2,
            'global_embed_dim': 32
        },
        'datasets': [
            {'name': 'table_a.csv', 'transformer_type': 'standard', 'complexity': 'small'},
            {'name': 'table_b.csv', 'transformer_type': 'standard', 'complexity': 'small'}
        ],
        'training': {
            'use_synthetic': True,
            'synthetic': {
                'n_samples': 512,
                'feature_dim': 8
            },
            'batch_size': 32,
            'epochs': 3,
            'optimizer': {'name': 'adam', 'lr': 1e-3},
            'split_config': {
                'test_size': 0.2,
                'validation_size': 0.2,
                'randomize': True
            }
        },
        'mlops': {
            'logging_provider': 'stdout',
            'experiment_name': 'synthetic_demo'
        }
    }
    
    # Create config object
    config = ConfigModel.model_validate(synthetic_config)
    print("✅ Configuration created for synthetic data training")
    
    # Initialize trainer
    try:
        trainer = Trainer(config, work_dir=".")
        print("✅ Trainer initialized")
        
        # Run sanity check
        print("\n🔍 Running sanity check...")
        trainer.sanity_check()
        print("✅ Sanity check passed")
        
        # Train the model
        print("\n🚀 Starting training...")
        trainer.train()
        print("✅ Training completed!")
        
        # Evaluate the model
        print("\n📈 Evaluating model...")
        metrics = trainer.evaluate()
        
        if metrics:
            print("\n📊 Final Evaluation Results:")
            for metric, value in metrics.items():
                print(f"   {metric}: {value:.4f}")
        
        return config, trainer
        
    except Exception as e:
        print(f"❌ Training failed: {e}")
        return None, None

# %%
# Run synthetic training demo
synthetic_config, synthetic_trainer = run_synthetic_training_demo()
# Out:
# 2025-08-25 03:32:40.500 | INFO     | src.nexusflow.trainer.trainer:_setup_file_logging:171 - File logging enabled: results\logs\training_synthetic_demo.log
# 2025-08-25 03:32:40.506 | INFO     | src.nexusflow.trainer.trainer:__init__:105 - Enhanced Trainer initialized (device=cpu)
# 2025-08-25 03:32:40.512 | INFO     | src.nexusflow.trainer.trainer:_setup_data:178 - Using synthetic data mode
# 2025-08-25 03:32:40.518 | INFO     | src.nexusflow.trainer.trainer:_setup_data:187 - Synthetic data: 2 datasets × 8 features
# 2025-08-25 03:32:40.541 | INFO     | nexusflow.model.nexus_former:__init__:178 - NexusFormer initialized: 2 encoders, 2 iterations
# ============================================================
# 📊 SYNTHETIC DATA TRAINING DEMO
# ============================================================
# ✅ Configuration created for synthetic data training
# 2025-08-25 03:32:54.997 | INFO     | src.nexusflow.trainer.trainer:log_params:66 - Logging parameters: {'model_name': 'NexusFormer', 'input_dims': [8, 8], 'embed_dim': 32, 'refinement_iterations': 2, 'num_parameters': 46145, 'learning_rate': 0.001, 'optimizer': 'adam', 'batch_size': 32, 'epochs': 3}
# 2025-08-25 03:32:54.998 | INFO     | src.nexusflow.trainer.trainer:__init__:155 - Model initialized: 46145 parameters
# 2025-08-25 03:32:54.998 | INFO     | src.nexusflow.trainer.trainer:sanity_check:342 - Running comprehensive sanity checks...
# 2025-08-25 03:32:55.008 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([2, 32]) mean=0.0000
# 2025-08-25 03:32:55.009 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([2, 32])
# 2025-08-25 03:32:55.011 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([2, 32]) mean=0.0000
# 2025-08-25 03:32:55.013 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([2, 32])
# 2025-08-25 03:32:55.015 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.019 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 32])
# 2025-08-25 03:32:55.023 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.772422
# 2025-08-25 03:32:55.025 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 32])
# 2025-08-25 03:32:55.027 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.814881
# 2025-08-25 03:32:55.028 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.031 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 32])
# 2025-08-25 03:32:55.034 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.510359
# 2025-08-25 03:32:55.036 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 32])
# 2025-08-25 03:32:55.038 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.542525
# 2025-08-25 03:32:55.040 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([2, 64])
# 2025-08-25 03:32:55.043 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([2])
# 2025-08-25 03:32:55.045 | INFO     | src.nexusflow.trainer.trainer:sanity_check:352 - Model forward pass: output_shape=torch.Size([2])
# 2025-08-25 03:32:55.066 | INFO     | src.nexusflow.trainer.trainer:_setup_dataloaders:252 - Synthetic DataLoaders: train=12 val=3 test=3 batches
# 2025-08-25 03:32:55.069 | INFO     | src.nexusflow.trainer.trainer:sanity_check:365 - Sample batch: features=[torch.Size([32, 8]), torch.Size([32, 8])] targets=torch.Size([32])
# 2025-08-25 03:32:55.074 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0000
# 2025-08-25 03:32:55.076 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.079 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0000
# 2025-08-25 03:32:55.081 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.083 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.085 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.086 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.719646
# 2025-08-25 03:32:55.089 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.090 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.114388
# 2025-08-25 03:32:55.092 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.095 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.096 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.535641
# 2025-08-25 03:32:55.098 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.100 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.762696
# 2025-08-25 03:32:55.101 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.102 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.118 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0000
# 2025-08-25 03:32:55.119 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.121 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0000
# 2025-08-25 03:32:55.122 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.124 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.128 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.132 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.722616
# 2025-08-25 03:32:55.135 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.137 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.185578
# 2025-08-25 03:32:55.139 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.144 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.146 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.512194
# 2025-08-25 03:32:55.153 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.156 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.883484
# 2025-08-25 03:32:55.158 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.160 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.168 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([12, 32]) mean=0.0000
# 2025-08-25 03:32:55.170 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.174 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([12, 32]) mean=0.0000
# 2025-08-25 03:32:55.176 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([12, 32])
# ✅ Trainer initialized
#
# 🔍 Running sanity check...
# 2025-08-25 03:32:55.178 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.183 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.185 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.537369
# 2025-08-25 03:32:55.188 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.190 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.113461
# 2025-08-25 03:32:55.192 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.197 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.199 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.389723
# 2025-08-25 03:32:55.203 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.204 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.851439
# 2025-08-25 03:32:55.206 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([12, 64])
# 2025-08-25 03:32:55.208 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([12])
# 2025-08-25 03:32:55.215 | INFO     | src.nexusflow.trainer.trainer:sanity_check:370 - Initial validation metrics: {'accuracy': 0.5921052694320679, 'val_loss': 0.6927823225657145}
# 2025-08-25 03:32:55.217 | INFO     | src.nexusflow.trainer.trainer:sanity_check:372 - All sanity checks passed!
# 2025-08-25 03:32:55.218 | INFO     | src.nexusflow.trainer.trainer:train:377 - Starting enhanced training: 3 epochs
# 2025-08-25 03:32:55.223 | INFO     | src.nexusflow.trainer.trainer:_setup_dataloaders:252 - Synthetic DataLoaders: train=12 val=3 test=3 batches
# 2025-08-25 03:32:55.236 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0000
# 2025-08-25 03:32:55.237 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.244 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0000
# 2025-08-25 03:32:55.246 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.247 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.250 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.252 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.789800
# 2025-08-25 03:32:55.255 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.257 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.117986
# 2025-08-25 03:32:55.259 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.261 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.263 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.573174
# 2025-08-25 03:32:55.267 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.269 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.812659
# 2025-08-25 03:32:55.270 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.273 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.301 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0001
# 2025-08-25 03:32:55.302 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.307 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0002
# 2025-08-25 03:32:55.309 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.311 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.314 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.316 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.717870
# 2025-08-25 03:32:55.318 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.319 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.166600
# 2025-08-25 03:32:55.321 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.323 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.325 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.550684
# 2025-08-25 03:32:55.328 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.331 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.873963
# 2025-08-25 03:32:55.332 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.335 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.355 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0000
# 2025-08-25 03:32:55.356 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.361 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0004
# 2025-08-25 03:32:55.363 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.364 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.366 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.367 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.782464
# 2025-08-25 03:32:55.369 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.371 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.241658
# 2025-08-25 03:32:55.372 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.374 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.376 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.596125
# 2025-08-25 03:32:55.378 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.380 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.912349
# 2025-08-25 03:32:55.382 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.384 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.408 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0002
# ✅ Sanity check passed
#
# 🚀 Starting training...
# 2025-08-25 03:32:55.409 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.414 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0005
# 2025-08-25 03:32:55.415 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.416 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.419 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.421 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.726055
# 2025-08-25 03:32:55.424 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.426 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.229769
# 2025-08-25 03:32:55.429 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.431 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.433 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.501103
# 2025-08-25 03:32:55.435 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.437 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.895782
# 2025-08-25 03:32:55.438 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.441 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.465 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0001
# 2025-08-25 03:32:55.466 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.470 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0005
# 2025-08-25 03:32:55.471 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.472 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.475 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.477 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.754864
# 2025-08-25 03:32:55.480 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.482 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.188930
# 2025-08-25 03:32:55.484 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.486 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.488 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.530954
# 2025-08-25 03:32:55.491 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.492 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.813898
# 2025-08-25 03:32:55.495 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.497 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.517 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0001
# 2025-08-25 03:32:55.518 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.523 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0006
# 2025-08-25 03:32:55.525 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.526 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.529 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.531 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.785801
# 2025-08-25 03:32:55.533 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.534 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.187233
# 2025-08-25 03:32:55.535 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.538 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.539 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.531363
# 2025-08-25 03:32:55.542 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.544 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.888230
# 2025-08-25 03:32:55.546 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.548 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.567 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0001
# 2025-08-25 03:32:55.568 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.574 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0005
# 2025-08-25 03:32:55.575 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.577 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.581 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.583 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.662790
# 2025-08-25 03:32:55.586 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.588 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.124871
# 2025-08-25 03:32:55.590 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.592 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.594 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.590972
# 2025-08-25 03:32:55.597 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.599 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.877241
# 2025-08-25 03:32:55.600 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.602 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.619 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0001
# 2025-08-25 03:32:55.621 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.626 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0005
# 2025-08-25 03:32:55.628 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.629 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.631 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.632 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.718006
# 2025-08-25 03:32:55.634 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.636 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.261316
# 2025-08-25 03:32:55.637 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.639 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.641 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.531760
# 2025-08-25 03:32:55.643 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.645 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.799685
# 2025-08-25 03:32:55.647 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.649 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.668 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0003
# 2025-08-25 03:32:55.669 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.674 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0007
# 2025-08-25 03:32:55.676 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.677 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.683 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.685 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.682623
# 2025-08-25 03:32:55.688 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.690 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.149787
# 2025-08-25 03:32:55.692 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.695 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.700 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.516482
# 2025-08-25 03:32:55.704 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.707 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.812269
# 2025-08-25 03:32:55.708 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.712 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.748 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0004
# 2025-08-25 03:32:55.750 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.756 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0006
# 2025-08-25 03:32:55.757 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.759 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.762 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.764 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.723045
# 2025-08-25 03:32:55.767 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.769 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.164749
# 2025-08-25 03:32:55.770 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.772 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.774 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.509867
# 2025-08-25 03:32:55.777 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.778 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.839624
# 2025-08-25 03:32:55.780 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.781 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.798 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0002
# 2025-08-25 03:32:55.799 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.802 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0007
# 2025-08-25 03:32:55.803 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.804 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.806 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.808 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.782722
# 2025-08-25 03:32:55.811 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.812 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.218281
# 2025-08-25 03:32:55.813 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.815 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.817 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.525698
# 2025-08-25 03:32:55.819 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.820 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.868785
# 2025-08-25 03:32:55.821 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.823 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.841 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([6, 32]) mean=0.0003
# 2025-08-25 03:32:55.843 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([6, 32])
# 2025-08-25 03:32:55.847 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([6, 32]) mean=-0.0008
# 2025-08-25 03:32:55.848 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([6, 32])
# 2025-08-25 03:32:55.848 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.850 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:55.851 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.802954
# 2025-08-25 03:32:55.853 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:55.855 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.049233
# 2025-08-25 03:32:55.856 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.859 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:55.860 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.500559
# 2025-08-25 03:32:55.862 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:55.864 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.844284
# 2025-08-25 03:32:55.865 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([6, 64])
# 2025-08-25 03:32:55.866 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([6])
# 2025-08-25 03:32:55.897 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0004
# 2025-08-25 03:32:55.898 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.901 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0004
# 2025-08-25 03:32:55.902 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.904 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.906 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.908 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.769353
# 2025-08-25 03:32:55.910 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.911 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.119371
# 2025-08-25 03:32:55.912 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.914 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.915 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.497861
# 2025-08-25 03:32:55.917 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.918 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.733156
# 2025-08-25 03:32:55.920 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.922 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.926 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0004
# 2025-08-25 03:32:55.927 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.930 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0005
# 2025-08-25 03:32:55.931 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.932 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.933 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.935 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.732527
# 2025-08-25 03:32:55.937 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.938 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.229682
# 2025-08-25 03:32:55.940 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.941 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.943 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.442094
# 2025-08-25 03:32:55.945 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:55.947 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.869885
# 2025-08-25 03:32:55.948 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:55.949 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:55.952 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([12, 32]) mean=0.0006
# 2025-08-25 03:32:55.954 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.956 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([12, 32]) mean=-0.0006
# 2025-08-25 03:32:55.958 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.959 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:55.961 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.963 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.579067
# 2025-08-25 03:32:55.964 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.966 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.153744
# 2025-08-25 03:32:55.967 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:55.968 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.970 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.340685
# 2025-08-25 03:32:55.972 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:55.973 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.864079
# 2025-08-25 03:32:55.975 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([12, 64])
# 2025-08-25 03:32:55.977 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([12])
# 2025-08-25 03:32:55.979 | INFO     | src.nexusflow.trainer.trainer:log_metrics:51 - Metrics (step 1): train_loss=0.688897 epoch=1.000000 epoch_time=0.753045 accuracy=0.618421 val_loss=0.688052
# 2025-08-25 03:32:55.981 | INFO     | src.nexusflow.trainer.trainer:train:434 - New best model at epoch 1: 0.688052
# 2025-08-25 03:32:55.999 | DEBUG    | src.nexusflow.trainer.trainer:_save_checkpoint:477 - Checkpoint saved: model_epoch_1.pt
# 2025-08-25 03:32:56.001 | INFO     | src.nexusflow.trainer.trainer:train:440 - Epoch 1/3: train_loss=0.688897 val_loss=0.6880520383516947 time=0.75s
# 2025-08-25 03:32:56.006 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0004
# 2025-08-25 03:32:56.007 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.010 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0005
# 2025-08-25 03:32:56.011 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.012 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:56.014 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.016 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.699806
# 2025-08-25 03:32:56.017 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.019 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.159258
# 2025-08-25 03:32:56.020 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:56.023 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.025 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.542391
# 2025-08-25 03:32:56.027 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.028 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.845122
# 2025-08-25 03:32:56.030 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:56.033 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:56.052 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0000
# 2025-08-25 03:32:56.054 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.060 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0002
# 2025-08-25 03:32:56.061 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.062 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:56.064 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.065 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.752532
# 2025-08-25 03:32:56.067 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.069 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.239814
# 2025-08-25 03:32:56.070 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:56.072 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.073 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.549831
# 2025-08-25 03:32:56.076 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.078 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.818814
# 2025-08-25 03:32:56.079 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:56.087 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:56.122 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0005
# 2025-08-25 03:32:56.124 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.131 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=-0.0002
# 2025-08-25 03:32:56.132 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.134 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:56.137 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.139 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.869273
# 2025-08-25 03:32:56.141 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.142 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.157345
# 2025-08-25 03:32:56.143 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:56.145 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.146 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.541118
# 2025-08-25 03:32:56.149 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:56.151 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.846773
# 2025-08-25 03:32:56.154 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# ...
# 2025-08-25 03:32:57.369 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([6, 32])
# 2025-08-25 03:32:57.371 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:57.373 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:57.374 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.843920
# 2025-08-25 03:32:57.377 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:57.378 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.340151
# 2025-08-25 03:32:57.380 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:57.382 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:57.383 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.706606
# 2025-08-25 03:32:57.385 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([6, 32])
# 2025-08-25 03:32:57.387 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.654096
# 2025-08-25 03:32:57.388 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([6, 64])
# 2025-08-25 03:32:57.390 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([6])
# 2025-08-25 03:32:57.403 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0011
# 2025-08-25 03:32:57.405 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.407 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0006
# 2025-08-25 03:32:57.409 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.410 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:57.412 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.413 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.838783
# 2025-08-25 03:32:57.415 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.416 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.254486
# 2025-08-25 03:32:57.417 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:57.419 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.421 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.525335
# 2025-08-25 03:32:57.423 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.424 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.797080
# 2025-08-25 03:32:57.425 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:57.426 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:57.433 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0009
# 2025-08-25 03:32:57.435 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.440 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0007
# 2025-08-25 03:32:57.441 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.442 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:57.444 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.446 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.771890
# 2025-08-25 03:32:57.448 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.450 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.378309
# 2025-08-25 03:32:57.450 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:57.452 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.454 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.457013
# 2025-08-25 03:32:57.456 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.458 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.904511
# 2025-08-25 03:32:57.463 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:57.466 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:57.471 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([12, 32]) mean=0.0013
# 2025-08-25 03:32:57.473 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([12, 32])
# 2025-08-25 03:32:57.482 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([12, 32]) mean=0.0009
# 2025-08-25 03:32:57.483 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([12, 32])
# 2025-08-25 03:32:57.485 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:57.488 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:57.491 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.629565
# 2025-08-25 03:32:57.493 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:57.495 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.262845
# 2025-08-25 03:32:57.497 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:57.499 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:57.502 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.381287
# 2025-08-25 03:32:57.505 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([12, 32])
# 2025-08-25 03:32:57.507 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.957090
# 2025-08-25 03:32:57.509 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([12, 64])
# 2025-08-25 03:32:57.511 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([12])
# 2025-08-25 03:32:57.513 | INFO     | src.nexusflow.trainer.trainer:log_metrics:51 - Metrics (step 3): train_loss=0.675328 epoch=3.000000 epoch_time=0.792618 accuracy=0.592105 val_loss=0.688819
# 2025-08-25 03:32:57.529 | DEBUG    | src.nexusflow.trainer.trainer:_save_checkpoint:477 - Checkpoint saved: model_epoch_3.pt
# 2025-08-25 03:32:57.530 | INFO     | src.nexusflow.trainer.trainer:train:440 - Epoch 3/3: train_loss=0.675328 val_loss=0.6888193289438883 time=0.79s
# 2025-08-25 03:32:57.540 | INFO     | src.nexusflow.trainer.trainer:_save_best_model:497 - Best model saved: best_model.pt
# 2025-08-25 03:32:57.551 | INFO     | nexusflow.model.nexus_former:__init__:178 - NexusFormer initialized: 2 encoders, 2 iterations
# 2025-08-25 03:32:57.555 | INFO     | nexusflow.api.model_api:__init__:37 - NexusFlow model artifact initialized with 2 input dimensions
# 2025-08-25 03:32:57.562 | INFO     | nexusflow.api.model_api:save:319 - NexusFlow model artifact saved to: synthetic_demo.nxf
# 2025-08-25 03:32:57.563 | INFO     | src.nexusflow.trainer.trainer:_create_model_artifact:530 - Model artifact created: synthetic_demo.nxf
# 2025-08-25 03:32:57.566 | INFO     | src.nexusflow.trainer.trainer:train:459 - Training complete! Best model at epoch 2 with metric 0.686893
# 2025-08-25 03:32:57.568 | INFO     | src.nexusflow.trainer.trainer:evaluate:538 - Running comprehensive evaluation on test set...
# 2025-08-25 03:32:57.571 | INFO     | src.nexusflow.trainer.trainer:evaluate:543 - Using best model from epoch 2
# 2025-08-25 03:32:57.578 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0009
# 2025-08-25 03:32:57.579 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.581 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0006
# 2025-08-25 03:32:57.582 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.584 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:57.585 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.588 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.724034
# 2025-08-25 03:32:57.591 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.593 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.226846
# 2025-08-25 03:32:57.594 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:57.596 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.598 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.504060
# 2025-08-25 03:32:57.600 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.601 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.830754
# 2025-08-25 03:32:57.602 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:57.603 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:57.607 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0011
# 2025-08-25 03:32:57.609 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.611 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([32, 32]) mean=0.0006
# 2025-08-25 03:32:57.612 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.613 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:57.615 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.616 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.761082
# 2025-08-25 03:32:57.618 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.620 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.252582
# 2025-08-25 03:32:57.622 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:57.624 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.625 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.470242
# 2025-08-25 03:32:57.627 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([32, 32])
# 2025-08-25 03:32:57.628 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.790610
# 2025-08-25 03:32:57.629 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([32, 64])
# 2025-08-25 03:32:57.631 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([32])
# 2025-08-25 03:32:57.633 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([14, 32]) mean=0.0007
# 2025-08-25 03:32:57.635 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([14, 32])
# 2025-08-25 03:32:57.637 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([14, 32]) mean=0.0005
# 2025-08-25 03:32:57.639 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([14, 32])
# 2025-08-25 03:32:57.640 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/2
# 2025-08-25 03:32:57.642 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([14, 32])
# 2025-08-25 03:32:57.644 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.785796
# 2025-08-25 03:32:57.645 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([14, 32])
# 2025-08-25 03:32:57.646 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 2.422084
# 2025-08-25 03:32:57.647 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/2
# 2025-08-25 03:32:57.649 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([14, 32])
# 2025-08-25 03:32:57.650 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.460694
# 2025-08-25 03:32:57.651 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([14, 32])
# 2025-08-25 03:32:57.653 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.926940
# 2025-08-25 03:32:57.655 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([14, 64])
# 2025-08-25 03:32:57.657 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([14])
# 2025-08-25 03:32:57.658 | INFO     | src.nexusflow.trainer.trainer:log_metrics:51 - Metrics (step 2): accuracy=0.474359 test_loss=0.711513 num_test_samples=78.000000 num_test_batches=3.000000
# 2025-08-25 03:32:57.659 | INFO     | src.nexusflow.trainer.trainer:evaluate:582 - Final evaluation metrics: {'accuracy': 0.4743589758872986, 'test_loss': 0.7115134994188944, 'num_test_samples': 78, 'num_test_batches': 3}
# ✅ Training completed!
#
# 📈 Evaluating model...
#
# 📊 Final Evaluation Results:
#    accuracy: 0.4744
#    test_loss: 0.7115
#    num_test_samples: 78.0000
#    num_test_batches: 3.0000

# %% [markdown]
# # 🗂️ Section 4: Real Data Preparation & Training

# %%
def create_sample_datasets():
    """Create sample CSV files to demonstrate real data training."""
    print("\n" + "="*60)
    print("🗂️  SAMPLE DATA CREATION")
    print("="*60)
    
    # Ensure datasets directory exists
    datasets_dir = Path("datasets")
    datasets_dir.mkdir(exist_ok=True)
    
    np.random.seed(42)  # For reproducibility
    n_customers = 1000
    
    # 1. Create customers table (demographics + target)
    customers_data = {
        'customer_id': range(1, n_customers + 1),
        'age': np.random.normal(35, 12, n_customers).clip(18, 80).astype(int),
        'income': np.random.lognormal(10.5, 0.5, n_customers).clip(20000, 200000).astype(int),
        'tenure_months': np.random.exponential(24, n_customers).clip(1, 120).astype(int),
        'region': np.random.choice(['North', 'South', 'East', 'West'], n_customers),
        'has_churned': np.random.binomial(1, 0.15, n_customers)  # 15% churn rate
    }
    
    customers_df = pd.DataFrame(customers_data)
    customers_df.to_csv("datasets/customers.csv", index=False)
    print(f"✅ Created customers.csv: {customers_df.shape}")
    
    # 2. Create transactions table (behavioral data)
    # Generate multiple transactions per customer
    transactions_data = []
    for customer_id in range(1, n_customers + 1):
        n_transactions = np.random.poisson(8)  # Average 8 transactions per customer
        for _ in range(n_transactions):
            transactions_data.append({
                'customer_id': customer_id,
                'transaction_amount': np.clip(np.random.lognormal(3, 1), 5, 1000),
                'days_since_last': np.clip(np.random.exponential(15), 1, 90),
                'transaction_type': np.random.choice(['online', 'store', 'phone'], p=[0.6, 0.3, 0.1])
            })
    
    transactions_df = pd.DataFrame(transactions_data)
    
    # Aggregate transactions by customer for this demo
    agg_transactions = transactions_df.groupby('customer_id').agg({
        'transaction_amount': ['mean', 'std', 'count'],
        'days_since_last': ['mean', 'min']
    }).round(2)
    
    # Flatten column names
    agg_transactions.columns = ['_'.join(col).strip() for col in agg_transactions.columns]
    agg_transactions = agg_transactions.reset_index()
    
    # Add transaction type preferences
    type_counts = transactions_df.groupby('customer_id')['transaction_type'].value_counts().unstack(fill_value=0)
    type_proportions = type_counts.div(type_counts.sum(axis=1), axis=0).round(3)
    type_proportions = type_proportions.reset_index()
    
    transactions_final = agg_transactions.merge(type_proportions, on='customer_id')
    transactions_final.to_csv("datasets/transactions.csv", index=False)
    print(f"✅ Created transactions.csv: {transactions_final.shape}")
    
    # 3. Create support tickets table (text-like features)
    support_data = []
    for customer_id in range(1, n_customers + 1):
        if np.random.random() < 0.3:  # 30% of customers have support tickets
            n_tickets = np.random.poisson(2) + 1
            for _ in range(n_tickets):
                support_data.append({
                    'customer_id': customer_id,
                    'ticket_priority': np.random.choice(['low', 'medium', 'high'], p=[0.5, 0.4, 0.1]),
                    'resolution_days': np.clip(np.random.exponential(3), 1, 30),
                    'satisfaction_score': np.clip(np.random.normal(3.5, 1), 1, 5)
                })
    
    if support_data:
        support_df = pd.DataFrame(support_data)
        
        # Aggregate support tickets by customer
        agg_support = support_df.groupby('customer_id').agg({
            'resolution_days': ['mean', 'max'],
            'satisfaction_score': ['mean', 'min']
        }).round(2)
        
        agg_support.columns = ['_'.join(col).strip() for col in agg_support.columns]
        agg_support = agg_support.reset_index()
        
        # Add priority distributions
        priority_counts = support_df.groupby('customer_id')['ticket_priority'].value_counts().unstack(fill_value=0)
        priority_props = priority_counts.div(priority_counts.sum(axis=1), axis=0).round(3)
        priority_props.columns = [f'priority_{col}_pct' for col in priority_props.columns]
        priority_props = priority_props.reset_index()
        
        support_final = agg_support.merge(priority_props, on='customer_id', how='left').fillna(0)
        support_final.to_csv("datasets/support.csv", index=False)
        print(f"✅ Created support.csv: {support_final.shape}")
    
    print(f"\n📋 Dataset Summary:")
    print(f"   Customers: {len(customers_df)} records")
    print(f"   Transactions: {len(transactions_final)} aggregated records") 
    print(f"   Support: {len(support_final) if 'support_final' in locals() else 0} records")
    
    return True

# %%
def demo_real_data_training():
    """Demonstrate training with real CSV data."""
    print("\n" + "="*60)
    print("📈 REAL DATA TRAINING DEMO")
    print("="*60)
    
    # First create sample data
    create_sample_datasets()
    
    # Create configuration for real data
    real_data_config = {
        'project_name': 'churn_prediction',
        'primary_key': 'customer_id',
        'target': {
            'target_table': 'customers.csv',
            'target_column': 'has_churned'
        },
        'architecture': {
            'refinement_iterations': 3,
            'global_embed_dim': 64
        },
        'datasets': [
            {'name': 'customers.csv', 'transformer_type': 'standard', 'complexity': 'medium'},
            {'name': 'transactions.csv', 'transformer_type': 'standard', 'complexity': 'medium'},
            {'name': 'support.csv', 'transformer_type': 'standard', 'complexity': 'small'}
        ],
        'training': {
            'use_synthetic': False,  # Use real data
            'batch_size': 64,
            'epochs': 5,
            'optimizer': {'name': 'adam', 'lr': 5e-4},
            'split_config': {
                'test_size': 0.15,
                'validation_size': 0.15,
                'randomize': True
            }
        },
        'mlops': {
            'logging_provider': 'stdout',
            'experiment_name': 'churn_prediction_v1'
        }
    }
    
    config = ConfigModel.model_validate(real_data_config)
    print("✅ Configuration created for real data training")
    
    # Initialize and train
    try:
        trainer = Trainer(config, work_dir=".")
        print("✅ Trainer initialized with real data")
        
        # Show data summary
        print("\n📊 Data Summary:")
        if trainer.datasets:
            for name, df in trainer.datasets.items():
                missing_pct = df.isnull().sum().sum() / df.size * 100
                print(f"   {name}: {df.shape} ({missing_pct:.1f}% missing)")
        print(f"   Input dimensions: {trainer.input_dims}")
        
        # Run sanity check
        print("\n🔍 Running comprehensive data validation...")
        trainer.sanity_check()
        print("✅ Data validation passed")
        
        # Train the model
        print("\n🚀 Training on real data...")
        trainer.train()
        print("✅ Real data training completed!")
        
        # Evaluate
        print("\n📈 Final evaluation...")
        metrics = trainer.evaluate()
        
        if metrics:
            print("\n🎯 Model Performance:")
            for metric, value in metrics.items():
                if 'accuracy' in metric:
                    print(f"   {metric}: {value:.2%}")
                else:
                    print(f"   {metric}: {value:.4f}")
        
        return config, trainer
        
    except Exception as e:
        print(f"❌ Real data training failed: {e}")
        import traceback
        traceback.print_exc()
        return None, None

# %%
# Run real data training demo
real_config, real_trainer = demo_real_data_training()
# Out:
# ============================================================
# 📈 REAL DATA TRAINING DEMO
# ============================================================
#
# ============================================================
# 🗂️  SAMPLE DATA CREATION
# ============================================================
# ✅ Created customers.csv: (1000, 6)
# ✅ Created transactions.csv: (1000, 9)
# ✅ Created support.csv: (307, 8)
#
# 📋 Dataset Summary:
#    Customers: 1000 records
#    Transactions: 1000 aggregated records
#    Support: 307 records
# ✅ Configuration created for real data training
# 2025-08-25 19:43:38.615 | INFO     | src.nexusflow.trainer.trainer:_setup_file_logging:171 - File logging enabled: results\logs\training_churn_prediction_v1.log
# 2025-08-25 19:43:38.618 | INFO     | src.nexusflow.trainer.trainer:__init__:105 - Enhanced Trainer initialized (device=cpu)
# 2025-08-25 19:43:38.619 | INFO     | src.nexusflow.trainer.trainer:_setup_data:190 - Loading and aligning real datasets...
# 2025-08-25 19:43:38.645 | INFO     | nexusflow.data.ingestion:load_table:24 - Loaded table: datasets/customers.csv rows=1000 cols=6
# 2025-08-25 19:43:38.646 | INFO     | nexusflow.data.ingestion:load_table:25 - Missing values: total=0 (0.0%)
# 2025-08-25 19:43:38.648 | DEBUG    | nexusflow.data.ingestion:load_table:30 - No missing values found
# 2025-08-25 19:43:38.650 | INFO     | nexusflow.data.ingestion:load_datasets:67 - Dataset customers.csv: shape=(1000, 6), missing_values=0
# 2025-08-25 19:43:38.670 | INFO     | nexusflow.data.ingestion:load_table:24 - Loaded table: datasets/transactions.csv rows=1000 cols=9
# 2025-08-25 19:43:38.671 | INFO     | nexusflow.data.ingestion:load_table:25 - Missing values: total=1 (0.0%)
# 2025-08-25 19:43:38.673 | INFO     | nexusflow.data.ingestion:load_table:28 - Missing by column: {'transaction_amount_std': 1}
# 2025-08-25 19:43:38.678 | INFO     | nexusflow.data.ingestion:load_datasets:67 - Dataset transactions.csv: shape=(1000, 9), missing_values=1
# 2025-08-25 19:43:38.684 | DEBUG    | nexusflow.data.ingestion:load_datasets:70 - Missing values by column in transactions.csv: {'customer_id': 0, 'transaction_amount_mean': 0, 'transaction_amount_std': 1, 'transaction_amount_count': 0, 'days_since_last_mean': 0, 'days_since_last_min': 0, 'online': 0, 'phone': 0, 'store': 0}
# 2025-08-25 19:43:38.704 | INFO     | nexusflow.data.ingestion:load_table:24 - Loaded table: datasets/support.csv rows=307 cols=8
# 2025-08-25 19:43:38.706 | INFO     | nexusflow.data.ingestion:load_table:25 - Missing values: total=0 (0.0%)
# 2025-08-25 19:43:38.708 | DEBUG    | nexusflow.data.ingestion:load_table:30 - No missing values found
# 2025-08-25 19:43:38.711 | INFO     | nexusflow.data.ingestion:load_datasets:67 - Dataset support.csv: shape=(307, 8), missing_values=0
# 2025-08-25 19:43:38.713 | DEBUG    | nexusflow.data.ingestion:align_datasets:98 - Dataset customers.csv: 1000 unique keys
# 2025-08-25 19:43:38.715 | DEBUG    | nexusflow.data.ingestion:align_datasets:98 - Dataset transactions.csv: 1000 unique keys
# 2025-08-25 19:43:38.717 | DEBUG    | nexusflow.data.ingestion:align_datasets:98 - Dataset support.csv: 307 unique keys
# 2025-08-25 19:43:38.718 | INFO     | nexusflow.data.ingestion:align_datasets:100 - Found 307 common keys across all datasets
# 2025-08-25 19:43:38.722 | DEBUG    | nexusflow.data.ingestion:align_datasets:111 - Aligned customers.csv: 307 rows
# 2025-08-25 19:43:38.725 | DEBUG    | nexusflow.data.ingestion:align_datasets:111 - Aligned transactions.csv: 307 rows
# 2025-08-25 19:43:38.729 | DEBUG    | nexusflow.data.ingestion:align_datasets:111 - Aligned support.csv: 307 rows
# 2025-08-25 19:43:38.731 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset customers.csv: 4 features from columns ['age', 'income', 'tenure_months', 'region']
# 2025-08-25 19:43:38.733 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset transactions.csv: 8 features from columns ['transaction_amount_mean', 'transaction_amount_std', 'transaction_amount_count', 'days_since_last_mean', 'days_since_last_min', 'online', 'phone', 'store']
# 2025-08-25 19:43:38.734 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset support.csv: 7 features from columns ['resolution_days_mean', 'resolution_days_max', 'satisfaction_score_mean', 'satisfaction_score_min', 'priority_high_pct', 'priority_low_pct', 'priority_medium_pct']
# 2025-08-25 19:43:38.735 | INFO     | src.nexusflow.trainer.trainer:_setup_data:203 - Data alignment complete:
# 2025-08-25 19:43:38.736 | INFO     | src.nexusflow.trainer.trainer:_setup_data:204 -   Aligned samples: 307
# 2025-08-25 19:43:38.737 | INFO     | src.nexusflow.trainer.trainer:_setup_data:205 -   Datasets: 3
# 2025-08-25 19:43:38.739 | INFO     | src.nexusflow.trainer.trainer:_setup_data:206 -   Feature dimensions: [4, 8, 7]
# 2025-08-25 19:43:38.740 | INFO     | src.nexusflow.trainer.trainer:_setup_data:207 -   Total features: 19
# 2025-08-25 19:43:38.742 | DEBUG    | src.nexusflow.trainer.trainer:_setup_data:212 -   customers.csv: 0.00% missing values
# 2025-08-25 19:43:38.745 | DEBUG    | src.nexusflow.trainer.trainer:_setup_data:212 -   transactions.csv: 0.00% missing values
# 2025-08-25 19:43:38.746 | DEBUG    | src.nexusflow.trainer.trainer:_setup_data:212 -   support.csv: 0.00% missing values
# 2025-08-25 19:43:38.803 | INFO     | nexusflow.model.nexus_former:__init__:178 - NexusFormer initialized: 3 encoders, 3 iterations
# 2025-08-25 19:43:52.788 | INFO     | src.nexusflow.trainer.trainer:log_params:66 - Logging parameters: {'model_name': 'NexusFormer', 'input_dims': [4, 8, 7], 'embed_dim': 64, 'refinement_iterations': 3, 'num_parameters': 267585, 'learning_rate': 0.0005, 'optimizer': 'adam', 'batch_size': 64, 'epochs': 5}
# 2025-08-25 19:43:52.791 | INFO     | src.nexusflow.trainer.trainer:__init__:155 - Model initialized: 267585 parameters
# 2025-08-25 19:43:52.795 | INFO     | src.nexusflow.trainer.trainer:sanity_check:342 - Running comprehensive sanity checks...
# 2025-08-25 19:43:52.841 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([2, 64]) mean=-0.0000
# 2025-08-25 19:43:52.842 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 0: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.846 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([2, 64]) mean=0.0000
# 2025-08-25 19:43:52.847 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 1: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.849 | DEBUG    | nexusflow.model.nexus_former:forward:62 - StandardTabularEncoder output: shape=torch.Size([2, 64]) mean=0.0000
# 2025-08-25 19:43:52.851 | DEBUG    | nexusflow.model.nexus_former:forward:199 - Initial encoding 2: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.852 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 1/3
# 2025-08-25 19:43:52.864 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.868 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.970033
# 2025-08-25 19:43:52.870 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.871 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.951020
# 2025-08-25 19:43:52.874 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.875 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 2 attention change: 1.902286
# 2025-08-25 19:43:52.876 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 2/3
# 2025-08-25 19:43:52.878 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.879 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.833687
# 2025-08-25 19:43:52.882 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.884 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.893737
# 2025-08-25 19:43:52.885 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.887 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 2 attention change: 1.758716
# 2025-08-25 19:43:52.888 | DEBUG    | nexusflow.model.nexus_former:forward:203 - Refinement iteration 3/3
# 2025-08-25 19:43:52.890 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.891 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 0 attention change: 1.605164
# 2025-08-25 19:43:52.894 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.895 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 1 attention change: 1.708205
# 2025-08-25 19:43:52.897 | DEBUG    | nexusflow.model.nexus_former:forward:132 - CrossContextualAttention output: shape=torch.Size([2, 64])
# 2025-08-25 19:43:52.899 | DEBUG    | nexusflow.model.nexus_former:forward:218 - Encoder 2 attention change: 1.628226
# 2025-08-25 19:43:52.901 | DEBUG    | nexusflow.model.nexus_former:forward:224 - Final concatenated shape: torch.Size([2, 192])
# 2025-08-25 19:43:52.905 | DEBUG    | nexusflow.model.nexus_former:forward:228 - NexusFormer final output: shape=torch.Size([2])
# 2025-08-25 19:43:52.907 | INFO     | src.nexusflow.trainer.trainer:sanity_check:352 - Model forward pass: output_shape=torch.Size([2])
# 2025-08-25 19:43:52.912 | DEBUG    | nexusflow.data.ingestion:split_df:135 - Split sizes -> train=214 val=46 test=47
# 2025-08-25 19:43:52.917 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset customers.csv: 4 features from columns ['age', 'income', 'tenure_months', 'region']
# 2025-08-25 19:43:52.918 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset transactions.csv: 8 features from columns ['transaction_amount_mean', 'transaction_amount_std', 'transaction_amount_count', 'days_since_last_mean', 'days_since_last_min', 'online', 'phone', 'store']
# 2025-08-25 19:43:52.920 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset support.csv: 7 features from columns ['resolution_days_mean', 'resolution_days_max', 'satisfaction_score_mean', 'satisfaction_score_min', 'priority_high_pct', 'priority_low_pct', 'priority_medium_pct']
# 2025-08-25 19:43:52.924 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset customers.csv: 4 features from columns ['age', 'income', 'tenure_months', 'region']
# 2025-08-25 19:43:52.926 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset transactions.csv: 8 features from columns ['transaction_amount_mean', 'transaction_amount_std', 'transaction_amount_count', 'days_since_last_mean', 'days_since_last_min', 'online', 'phone', 'store']
# 2025-08-25 19:43:52.928 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset support.csv: 7 features from columns ['resolution_days_mean', 'resolution_days_max', 'satisfaction_score_mean', 'satisfaction_score_min', 'priority_high_pct', 'priority_low_pct', 'priority_medium_pct']
# 2025-08-25 19:43:52.933 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset customers.csv: 4 features from columns ['age', 'income', 'tenure_months', 'region']
# 2025-08-25 19:43:52.935 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset transactions.csv: 8 features from columns ['transaction_amount_mean', 'transaction_amount_std', 'transaction_amount_count', 'days_since_last_mean', 'days_since_last_min', 'online', 'phone', 'store']
# 2025-08-25 19:43:52.936 | DEBUG    | nexusflow.data.ingestion:get_feature_dimensions:162 - Dataset support.csv: 7 features from columns ['resolution_days_mean', 'resolution_days_max', 'satisfaction_score_mean', 'satisfaction_score_min', 'priority_high_pct', 'priority_low_pct', 'priority_medium_pct']
# 2025-08-25 19:43:52.939 | INFO     | nexusflow.data.ingestion:make_dataloaders:265 - Created DataLoaders: train=4 val=1 test=1 batches
# Traceback (most recent call last):
#   File "C:\Users\arkch\AppData\Local\Temp\ipykernel_36208\3067339289.py", line 62, in demo_real_data_training
#     trainer.sanity_check()
#   File "c:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\src\nexusflow\trainer\trainer.py", line 359, in sanity_check
#     sample_batch = next(iter(self.train_loader))
#   File "C:\Users\arkch\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#   File "C:\Users\arkch\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\dataloader.py", line 674, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "C:\Users\arkch\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\_utils\fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\arkch\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\_utils\fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "c:\Users\arkch\OneDrive\Documents\VS Code Workspace\python_files\ML_projects\Evoformer\src\nexusflow\data\dataset.py", line 49, in __getitem__
#     features = torch.tensor(row[self.feature_cols].values.astype('float32'))
# ValueError: could not convert string to float: 'South'
# ✅ Trainer initialized with real data
#
# 📊 Data Summary:
#    customers.csv: (307, 6) (0.0% missing)
#    transactions.csv: (307, 9) (0.0% missing)
#    support.csv: (307, 8) (0.0% missing)
#    Input dimensions: [4, 8, 7]
#
# 🔍 Running comprehensive data validation...
# ❌ Real data training failed: could not convert string to float: 'South'

# %% [markdown]
# # 🔍 Section 5: Model Inspection & Inference

# %%
def demonstrate_model_inference():
    """Show how to load and use trained models for inference."""
    print("\n" + "="*60)
    print("🔍 MODEL INFERENCE & INSPECTION")
    print("="*60)
    
    # Look for trained model files
    model_files = list(Path(".").glob("*.nxf"))
    
    if not model_files:
        print("⚠️  No .nxf model files found. Train a model first.")
        return
    
    # Use the most recent model file
    latest_model = max(model_files, key=lambda x: x.stat().st_mtime)
    print(f"📁 Loading model: {latest_model}")
    
    try:
        # Load the model artifact
        model = load_model(str(latest_model))
        print("✅ Model loaded successfully!")
        
        # Show model summary
        print("\n📋 Model Summary:")
        print(model.summary())
        
        # Show model parameters
        print("\n⚙️  Model Parameters:")
        params = model.get_params()
        key_params = ['total_parameters', 'input_dimensions', 'architecture', 'training_info']
        for key in key_params:
            if key in params:
                print(f"   {key}: {params[key]}")
        
        # Demonstrate inference with sample data
        print("\n🔮 Sample Inference:")
        
        # Create sample input data matching the model's expected format
        input_dims = params['input_dimensions']
        batch_size = 5
        
        # Generate random sample data
        sample_data = []
        for dim in input_dims:
            sample_table = pd.DataFrame(
                np.random.randn(batch_size, dim),
                columns=[f'feature_{i}' for i in range(dim)]
            )
            sample_data.append(sample_table)
        
        # Make predictions
        predictions = model.predict(sample_data)
        print(f"   Input: {len(sample_data)} tables with dims {input_dims}")
        print(f"   Output: {predictions.shape} predictions")
        print(f"   Sample predictions: {predictions[:3].round(4)}")
        
        # Try the visualization (placeholder)
        print("\n🎨 Model Visualization:")
        viz_info = model.visualize_flow()
        if viz_info:
            print(f"   Architecture: {viz_info.get('architecture')}")
            print(f"   Encoders: {viz_info.get('num_encoders')}")
            print(f"   Refinement iterations: {viz_info.get('refinement_iterations')}")
        
        return model
        
    except Exception as e:
        print(f"❌ Model loading/inference failed: {e}")
        import traceback
        traceback.print_exc()
        return None

# %%
# Run inference demo
loaded_model = demonstrate_model_inference()

# %% [markdown]
# # 📊 Section 6: Advanced Features & Analysis

# %%
def analyze_training_results():
    """Analyze and visualize training results."""
    print("\n" + "="*60)
    print("📊 TRAINING RESULTS ANALYSIS")
    print("="*60)
    
    # Look for results and logs
    results_dir = Path("results")
    if not results_dir.exists():
        print("⚠️  No results directory found")
        return
    
    # Check for metrics files
    metrics_file = results_dir / "metrics.json"
    if metrics_file.exists():
        import json
        with open(metrics_file) as f:
            metrics_data = json.load(f)
        
        print(f"✅ Found training metrics: {len(metrics_data)} logged steps")
        
        # Extract metrics for plotting
        steps = []
        train_losses = []
        val_losses = []
        
        for entry in metrics_data:
            if 'metrics' in entry and entry['step']:
                steps.append(entry['step'])
                train_losses.append(entry['metrics'].get('train_loss'))
                val_losses.append(entry['metrics'].get('val_loss'))
        
        # Create training curve plot
        if steps and train_losses:
            plt.figure(figsize=(12, 4))
            
            plt.subplot(1, 2, 1)
            plt.plot(steps, train_losses, 'b-', label='Training Loss', linewidth=2)
            if any(v is not None for v in val_losses):
                val_losses_clean = [v for v in val_losses if v is not None]
                val_steps = [s for s, v in zip(steps, val_losses) if v is not None]
                plt.plot(val_steps, val_losses_clean, 'r-', label='Validation Loss', linewidth=2)
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.title('Training Curves')
            plt.legend()
            plt.grid(True, alpha=0.3)
            
            # Model architecture visualization
            plt.subplot(1, 2, 2)
            if loaded_model:
                params = loaded_model.get_params()
                input_dims = params.get('input_dimensions', [])
                
                # Create a simple bar chart of input dimensions
                if input_dims:
                    plt.bar(range(len(input_dims)), input_dims, 
                           color=sns.color_palette("husl", len(input_dims)))
                    plt.xlabel('Encoder Index')
                    plt.ylabel('Input Features')
                    plt.title('Model Input Dimensions')
                    for i, dim in enumerate(input_dims):
                        plt.text(i, dim + max(input_dims)*0.01, str(dim), 
                               ha='center', va='bottom', fontweight='bold')
            
            plt.tight_layout()
            plt.show()
    
    # Look for checkpoint files
    checkpoint_files = list(Path(".").glob("model_epoch_*.pt"))
    if checkpoint_files:
        print(f"\n📁 Found {len(checkpoint_files)} training checkpoints")
        latest_checkpoint = max(checkpoint_files, key=lambda x: x.stat().st_mtime)
        print(f"   Latest: {latest_checkpoint.name}")
    
    # Check for best model
    best_model = Path("best_model.pt")
    if best_model.exists():
        print(f"✅ Best model checkpoint available: {best_model}")

# %%
def demonstrate_config_variations():
    """Show different configuration options and their effects."""
    print("\n" + "="*60)
    print("⚙️  CONFIGURATION VARIATIONS")
    print("="*60)
    
    configs = {
        "Minimal Setup": {
            'project_name': 'minimal_test',
            'primary_key': 'id',
            'target': {'target_table': 'data.csv', 'target_column': 'label'},
            'datasets': [{'name': 'data.csv'}],
            'architecture': {'global_embed_dim': 32},
            'training': {'use_synthetic': True, 'epochs': 2}
        },
        
        "Complex Multi-Table": {
            'project_name': 'complex_system',
            'primary_key': 'user_id', 
            'target': {'target_table': 'users.csv', 'target_column': 'conversion'},
            'datasets': [
                {'name': 'users.csv', 'transformer_type': 'standard', 'complexity': 'large'},
                {'name': 'events.csv', 'transformer_type': 'timeseries', 'complexity': 'medium'},
                {'name': 'content.csv', 'transformer_type': 'text', 'complexity': 'medium'}
            ],
            'architecture': {'global_embed_dim': 128, 'refinement_iterations': 5},
            'training': {'batch_size': 128, 'epochs': 50, 'optimizer': {'name': 'adam', 'lr': 1e-4}}
        },
        
        "High Performance": {
            'project_name': 'high_performance',
            'primary_key': 'sample_id',
            'target': {'target_table': 'outcomes.csv', 'target_column': 'target'},
            'datasets': [
                {'name': f'features_{i}.csv', 'complexity': 'medium'} for i in range(5)
            ],
            'architecture': {'global_embed_dim': 256, 'refinement_iterations': 8},
            'training': {
                'batch_size': 256, 
                'epochs': 100,
                'optimizer': {'name': 'adam', 'lr': 2e-4},
                'split_config': {'test_size': 0.1, 'validation_size': 0.1}
            }
        }
    }
    
    for name, config in configs.items():
        print(f"\n📋 {name}:")
        print(f"   Datasets: {len(config['datasets'])}")
        print(f"   Embedding dim: {config.get('architecture', {}).get('global_embed_dim', 64)}")
        print(f"   Epochs: {config.get('training', {}).get('epochs', 10)}")
        if 'refinement_iterations' in config.get('architecture', {}):
            print(f"   Refinement loops: {config['architecture']['refinement_iterations']}")

# %%
# Run analysis functions
analyze_training_results()
demonstrate_config_variations()

# %% [markdown]
# # 🎯 Section 7: Production Usage Patterns

# %%
def show_production_patterns():
    """Demonstrate production usage patterns and best practices."""
    print("\n" + "="*60)
    print("🎯 PRODUCTION USAGE PATTERNS")
    print("="*60)
    
    print("🔧 1. Batch Inference Pipeline:")
    print("""
    # Load trained model
    model = nexusflow.load_model('models/production_model.nxf')
    
    # Process new data in batches
    batch_size = 1000
    predictions = []
    
    for batch_data in data_loader:
        batch_pred = model.predict(batch_data)
        predictions.extend(batch_pred)
    """)
    
    print("\n🔧 2. API Endpoint Integration:")
    print("""
    from flask import Flask, request, jsonify
    import nexusflow
    
    app = Flask(__name__)
    model = nexusflow.load_model('production_model.nxf')
    
    @app.route('/predict', methods=['POST'])
    def predict():
        data = request.json
        # Convert JSON to required DataFrame format
        predictions = model.predict(data)
        return jsonify({'predictions': predictions.tolist()})
    """)
    
    print("\n🔧 3. Model Monitoring & Updates:")
    print("""
    # Performance monitoring
    def monitor_model_drift(model, new_data, reference_stats):
        current_stats = compute_data_statistics(new_data)
        drift_score = calculate_drift(current_stats, reference_stats)
        
        if drift_score > DRIFT_THRESHOLD:
            trigger_retraining_pipeline()
    
    # A/B testing framework
    def ab_test_models(model_a, model_b, test_data):
        predictions_a = model_a.predict(test_data)
        predictions_b = model_b.predict(test_data)
        
        # Compare performance metrics
        return compare_performance(predictions_a, predictions_b)
    """)
    
    print("\n🔧 4. MLOps Best Practices:")
    best_practices = [
        "Version control your config.yaml files",
        "Use experiment tracking (W&B, MLflow)",
        "Implement automated model validation",
        "Set up continuous integration for model training",
        "Monitor feature distributions in production",
        "Implement model rollback mechanisms",
        "Use feature stores for consistent data access",
        "Implement proper error handling and logging"
    ]
    
    for i, practice in enumerate(best_practices, 1):
        print(f"   {i}. {practice}")

# %%
def create_deployment_checklist():
    """Create a deployment readiness checklist."""
    print("\n📋 DEPLOYMENT READINESS CHECKLIST:")
    print("="*50)
    
    checklist_items = [
        ("✅", "Model trained and validated on representative data"),
        ("✅", "Configuration files version controlled"),
        ("✅", "Performance benchmarks established"),
        ("⚠️", "Data drift monitoring implemented"),
        ("⚠️", "A/B testing framework ready"),
        ("⚠️", "Model rollback procedure tested"),
        ("❌", "Production API endpoints implemented"),
        ("❌", "Monitoring and alerting configured"),
        ("❌", "Documentation and runbooks created"),
        ("❌", "Security review completed")
    ]
    
    for status, item in checklist_items:
        print(f"{status} {item}")

# %%
show_production_patterns()
create_deployment_checklist()

# %% [markdown]
# # 🎓 Section 8: Summary & Next Steps

# %%
def create_summary():
    """Create a comprehensive summary of what we've covered."""
    print("\n" + "="*60)
    print("🎓 TUTORIAL SUMMARY & NEXT STEPS")
    print("="*60)
    
    print("🏆 What You've Learned:")
    achievements = [
        "Project initialization and structure",
        "Configuration management with YAML",
        "Training with both synthetic and real data",
        "Multi-table data alignment and processing", 
        "Model evaluation and performance analysis",
        "Model artifact creation and inference",
        "Production deployment considerations"
    ]
    
    for achievement in achievements:
        print(f"   ✅ {achievement}")
    
    print("\n🚀 Next Steps to Explore:")
    next_steps = [
        "Experiment with different architectures (embed_dim, refinement_iterations)",
        "Try heterogeneous data types (text, timeseries)",
        "Implement custom encoders for domain-specific data",
        "Set up MLOps integration (W&B, MLflow)",
        "Build production API endpoints",
        "Implement model monitoring and drift detection",
        "Explore the visualization capabilities",
        "Contribute to the NexusFlow project"
    ]
    
    for i, step in enumerate(next_steps, 1):
        print(f"   {i}. {step}")
    
    print("\n📚 Key Resources:")
    resources = [
        "NexusFlow Documentation: Check project README",
        "Configuration Examples: See configs/ directory", 
        "API Reference: nexusflow.api.model_api module",
        "Model Architecture: nexusflow.model.nexus_former module",
        "Training Pipeline: nexusflow.trainer.trainer module"
    ]
    
    for resource in resources:
        print(f"   📖 {resource}")
    
    print("\n💡 Pro Tips:")
    tips = [
        "Start with synthetic data to validate your setup",
        "Use smaller embed_dim for faster prototyping",
        "Monitor validation loss to prevent overfitting", 
        "Experiment with different refinement_iterations",
        "Save your successful configurations for reuse",
        "Use the CLI for production training workflows"
    ]
    
    for tip in tips:
        print(f"   💡 {tip}")

# %%
create_summary()

# %%
print("\n" + "="*60)
print("🎉 Tutorial Complete!")
print("="*60)
print("Thank you for exploring NexusFlow!")
print("🔗 Ready to build your own multi-transformer tabular ecosystems!")

# %% [markdown]
# # 🛠️ Section 9: Interactive Utilities & Helper Functions

# %%
def create_interactive_model_explorer():
    """Create an interactive model exploration widget."""
    print("\n" + "="*60)
    print("🛠️  INTERACTIVE MODEL EXPLORER")
    print("="*60)
    
    def explore_model_architecture():
        """Interactive function to explore different architectures."""
        print("🏗️  Architecture Explorer")
        print("-" * 30)
        
        # Interactive parameter selection
        embed_dims = [32, 64, 128, 256]
        refinement_iterations = [1, 2, 3, 5, 8]
        
        print("Available embedding dimensions:", embed_dims)
        print("Available refinement iterations:", refinement_iterations)
        
        # Calculate parameter counts for different configurations
        print("\n📊 Parameter Count Estimates:")
        for embed_dim in [64, 128]:
            for ref_iter in [2, 5]:
                # Rough parameter estimate (simplified)
                encoder_params = embed_dim * 50  # Rough estimate per encoder
                attention_params = embed_dim * embed_dim * 4  # Q,K,V,O projections
                fusion_params = embed_dim * 3 * 32  # Fusion layers
                
                total_params = 2 * encoder_params + 2 * attention_params + fusion_params
                print(f"   embed_dim={embed_dim}, iterations={ref_iter}: ~{total_params:,} parameters")
        
        return embed_dims, refinement_iterations
    
    def model_performance_predictor():
        """Predict approximate training time and memory usage."""
        print("\n⏱️  Performance Predictor")
        print("-" * 30)
        
        configs = [
            {"name": "Small", "embed_dim": 32, "iterations": 2, "datasets": 2},
            {"name": "Medium", "embed_dim": 64, "iterations": 3, "datasets": 3}, 
            {"name": "Large", "embed_dim": 128, "iterations": 5, "datasets": 4},
            {"name": "XLarge", "embed_dim": 256, "iterations": 8, "datasets": 5}
        ]
        
        for config in configs:
            # Rough estimates based on typical hardware
            train_time_per_epoch = config["embed_dim"] * config["iterations"] * config["datasets"] * 0.001
            memory_mb = config["embed_dim"] * config["datasets"] * 0.5
            
            print(f"   {config['name']:>7}: ~{train_time_per_epoch:.1f}s/epoch, ~{memory_mb:.0f}MB memory")
    
    explore_model_architecture()
    model_performance_predictor()

# %%
def create_data_quality_analyzer():
    """Create tools for analyzing data quality and preparation."""
    print("\n" + "="*60)
    print("🔍 DATA QUALITY ANALYZER")
    print("="*60)
    
    def analyze_dataset_compatibility():
        """Check if datasets are compatible for NexusFlow training."""
        print("🔗 Dataset Compatibility Checker")
        print("-" * 35)
        
        # Check if our sample datasets exist
        dataset_files = ["customers.csv", "transactions.csv", "support.csv"]
        datasets_dir = Path("datasets")
        
        compatibility_report = {}
        
        for filename in dataset_files:
            filepath = datasets_dir / filename
            if filepath.exists():
                try:
                    df = pd.read_csv(filepath)
                    
                    # Analyze dataset characteristics
                    analysis = {
                        "shape": df.shape,
                        "missing_values": df.isnull().sum().sum(),
                        "missing_percentage": (df.isnull().sum().sum() / df.size) * 100,
                        "numeric_columns": len(df.select_dtypes(include=[np.number]).columns),
                        "categorical_columns": len(df.select_dtypes(include=['object']).columns),
                        "has_customer_id": 'customer_id' in df.columns,
                        "duplicate_ids": df['customer_id'].duplicated().sum() if 'customer_id' in df.columns else 0
                    }
                    
                    compatibility_report[filename] = analysis
                    
                    # Print summary
                    status = "✅" if analysis["missing_percentage"] < 10 and analysis["has_customer_id"] else "⚠️"
                    print(f"   {status} {filename}: {df.shape[0]:,} rows × {df.shape[1]} cols, {analysis['missing_percentage']:.1f}% missing")
                    
                except Exception as e:
                    print(f"   ❌ {filename}: Error reading file - {e}")
            else:
                print(f"   ❌ {filename}: File not found")
        
        return compatibility_report
    
    def suggest_data_improvements():
        """Suggest improvements for better model performance."""
        print("\n💡 Data Improvement Suggestions")
        print("-" * 35)
        
        suggestions = [
            "🔹 Feature Engineering: Create interaction features between tables",
            "🔹 Temporal Features: Add time-based aggregations (recent vs. historical)",
            "🔹 Categorical Encoding: Use target encoding for high-cardinality categories",
            "🔹 Missing Value Strategy: Consider domain-specific imputation methods",
            "🔹 Feature Scaling: Normalize numerical features within each table",
            "🔹 Outlier Treatment: Cap extreme values or use robust transformations",
            "🔹 Data Validation: Implement schema validation for production data",
            "🔹 Feature Selection: Remove highly correlated or low-variance features"
        ]
        
        for suggestion in suggestions:
            print(f"   {suggestion}")
    
    report = analyze_dataset_compatibility()
    suggest_data_improvements()
    
    return report

# %%
def create_experiment_tracker():
    """Create a simple experiment tracking utility."""
    print("\n" + "="*60)
    print("🧪 EXPERIMENT TRACKER")
    print("="*60)
    
    experiments_log = []
    
    def log_experiment(name, config, results=None):
        """Log an experiment configuration and results."""
        experiment = {
            "name": name,
            "timestamp": pd.Timestamp.now().isoformat(),
            "config": config,
            "results": results or {}
        }
        experiments_log.append(experiment)
        
        print(f"📝 Logged experiment: {name}")
        return len(experiments_log) - 1  # Return experiment ID
    
    def compare_experiments(exp_ids=None):
        """Compare multiple experiments."""
        if not experiments_log:
            print("No experiments logged yet")
            return
        
        if exp_ids is None:
            exp_ids = list(range(len(experiments_log)))
        
        print(f"🔍 Comparing {len(exp_ids)} experiments:")
        print("-" * 50)
        
        comparison_data = []
        for exp_id in exp_ids:
            if exp_id < len(experiments_log):
                exp = experiments_log[exp_id]
                
                # Extract key metrics
                config = exp.get("config", {})
                results = exp.get("results", {})
                
                row = {
                    "Name": exp["name"],
                    "Embed_Dim": config.get("architecture", {}).get("global_embed_dim", "N/A"),
                    "Refinements": config.get("architecture", {}).get("refinement_iterations", "N/A"),
                    "Epochs": config.get("training", {}).get("epochs", "N/A"),
                    "Batch_Size": config.get("training", {}).get("batch_size", "N/A"),
                    "Accuracy": results.get("accuracy", "N/A"),
                    "Loss": results.get("test_loss", "N/A")
                }
                comparison_data.append(row)
        
        if comparison_data:
            comparison_df = pd.DataFrame(comparison_data)
            display(comparison_df)
        
        return comparison_data
    
    # Log our demo experiments
    if 'synthetic_config' in locals() and synthetic_config:
        log_experiment("Synthetic Demo", synthetic_config.model_dump() if hasattr(synthetic_config, 'model_dump') else dict(synthetic_config))
    
    if 'real_config' in locals() and real_config:
        log_experiment("Real Data Demo", real_config.model_dump() if hasattr(real_config, 'model_dump') else dict(real_config))
    
    def save_experiments_log():
        """Save experiments to file."""
        if experiments_log:
            log_file = Path("experiments_log.json")
            import json
            with open(log_file, 'w') as f:
                json.dump(experiments_log, f, indent=2, default=str)
            print(f"💾 Saved experiments log to: {log_file}")
    
    print(f"📊 Current experiments logged: {len(experiments_log)}")
    if experiments_log:
        compare_experiments()
    
    return log_experiment, compare_experiments, save_experiments_log

# %%
# Run interactive utilities
create_interactive_model_explorer()
data_quality_report = create_data_quality_analyzer()
log_exp, compare_exp, save_exp_log = create_experiment_tracker()

# %% [markdown]
# # 🎨 Section 10: Advanced Visualization & Analysis

# %%
def create_advanced_visualizations():
    """Create advanced visualization tools for model analysis."""
    print("\n" + "="*60)
    print("🎨 ADVANCED VISUALIZATIONS")
    print("="*60)
    
    def plot_architecture_diagram():
        """Create a visual representation of the NexusFormer architecture."""
        print("🏗️  Architecture Visualization")
        print("-" * 35)
        
        if loaded_model:
            params = loaded_model.get_params()
            input_dims = params.get('input_dimensions', [64, 32, 16])
            embed_dim = params.get('architecture', {}).get('embed_dim', 64)
            refinement_iterations = params.get('architecture', {}).get('refinement_iterations', 3)
        else:
            # Use example values
            input_dims = [64, 32, 16]
            embed_dim = 64
            refinement_iterations = 3
        
        fig, axes = plt.subplots(2, 2, figsize=(15, 10))
        
        # 1. Input Dimensions
        ax1 = axes[0, 0]
        colors = sns.color_palette("viridis", len(input_dims))
        bars = ax1.bar(range(len(input_dims)), input_dims, color=colors)
        ax1.set_title('Input Dimensions per Encoder')
        ax1.set_xlabel('Encoder Index')
        ax1.set_ylabel('Feature Count')
        
        # Add value labels on bars
        for bar, dim in zip(bars, input_dims):
            height = bar.get_height()
            ax1.text(bar.get_x() + bar.get_width()/2., height,
                    f'{dim}', ha='center', va='bottom', fontweight='bold')
        
        # 2. Architecture Flow
        ax2 = axes[0, 1]
        ax2.set_title('NexusFormer Information Flow')
        
        # Create a simplified flow diagram
        y_positions = np.arange(len(input_dims))
        x_encoder = [0] * len(input_dims)
        x_attention = [2] * len(input_dims)
        x_fusion = [4]
        
        # Plot encoders
        ax2.scatter(x_encoder, y_positions, s=200, c=colors, alpha=0.7, label='Encoders')
        
        # Plot attention mechanisms
        ax2.scatter(x_attention, y_positions, s=150, c='red', marker='s', alpha=0.7, label='Cross-Attention')
        
        # Plot fusion
        ax2.scatter(x_fusion, [len(input_dims)//2], s=300, c='gold', marker='D', label='Fusion Layer')
        
        # Draw connections
        for i in y_positions:
            # Encoder to attention
            ax2.arrow(0.1, i, 1.7, 0, head_width=0.1, head_length=0.1, fc='gray', ec='gray', alpha=0.5)
            # Attention to fusion
            ax2.arrow(2.1, i, 1.5, len(input_dims)//2 - i - 0.1, head_width=0.1, head_length=0.1, fc='gray', ec='gray', alpha=0.5)
        
        ax2.set_xlim(-0.5, 5)
        ax2.set_ylim(-0.5, len(input_dims) + 0.5)
        ax2.set_xticks([0, 2, 4])
        ax2.set_xticklabels(['Encoders', 'Cross-Attention', 'Fusion'])
        ax2.set_yticks(range(len(input_dims)))
        ax2.set_yticklabels([f'Table {i+1}' for i in range(len(input_dims))])
        ax2.legend()
        ax2.grid(True, alpha=0.3)
        
        # 3. Parameter Distribution
        ax3 = axes[1, 0]
        
        # Estimate parameter distribution
        encoder_params = sum(dim * embed_dim for dim in input_dims)
        attention_params = len(input_dims) * embed_dim * embed_dim * 4  # Q,K,V,O
        fusion_params = len(input_dims) * embed_dim * 64  # Rough estimate
        
        param_categories = ['Encoders', 'Cross-Attention', 'Fusion']
        param_counts = [encoder_params, attention_params, fusion_params]
        
        wedges, texts, autotexts = ax3.pie(param_counts, labels=param_categories, autopct='%1.1f%%', startangle=90)
        ax3.set_title('Parameter Distribution (Estimated)')
        
        # 4. Refinement Process
        ax4 = axes[1, 1]
        iterations = list(range(refinement_iterations + 1))
        
        # Simulate attention convergence (for illustration)
        np.random.seed(42)
        attention_changes = [1.0] + [np.exp(-i * 0.5) + np.random.normal(0, 0.1) for i in range(1, refinement_iterations + 1)]
        attention_changes = [max(0, x) for x in attention_changes]  # Ensure non-negative
        
        ax4.plot(iterations, attention_changes, 'o-', linewidth=2, markersize=8)
        ax4.set_title('Attention Refinement Process')
        ax4.set_xlabel('Refinement Iteration')
        ax4.set_ylabel('Attention Change Magnitude')
        ax4.grid(True, alpha=0.3)
        ax4.set_ylim(0, max(attention_changes) * 1.1)
        
        plt.tight_layout()
        plt.show()
        
        return fig
    
    def plot_data_quality_heatmap():
        """Create a heatmap showing data quality metrics."""
        print("\n📊 Data Quality Heatmap")
        print("-" * 30)
        
        if data_quality_report:
            # Convert quality report to matrix form
            metrics = ['missing_percentage', 'numeric_columns', 'categorical_columns']
            datasets = list(data_quality_report.keys())
            
            quality_matrix = []
            for dataset in datasets:
                row = []
                for metric in metrics:
                    value = data_quality_report[dataset].get(metric, 0)
                    if metric == 'missing_percentage':
                        # Invert missing percentage (lower is better)
                        value = max(0, 100 - value)
                    row.append(value)
                quality_matrix.append(row)
            
            quality_df = pd.DataFrame(quality_matrix, index=datasets, columns=metrics)
            
            plt.figure(figsize=(10, 6))
            sns.heatmap(quality_df, annot=True, fmt='.1f', cmap='RdYlGn', 
                       cbar_kws={'label': 'Quality Score'})
            plt.title('Dataset Quality Overview')
            plt.xlabel('Quality Metrics')
            plt.ylabel('Datasets')
            plt.tight_layout()
            plt.show()
    
    def create_feature_importance_plot():
        """Simulate and plot feature importance analysis."""
        print("\n🎯 Feature Importance Analysis")
        print("-" * 35)
        
        # Simulate feature importance scores
        np.random.seed(42)
        
        if loaded_model:
            params = loaded_model.get_params()
            input_dims = params.get('input_dimensions', [])
        else:
            input_dims = [10, 8, 6]
        
        # Create mock feature importance data
        all_features = []
        all_importance = []
        
        for table_idx, dim in enumerate(input_dims):
            table_name = f"Table_{table_idx + 1}"
            for feat_idx in range(dim):
                feature_name = f"{table_name}_feat_{feat_idx + 1}"
                # Simulate decreasing importance with some randomness
                importance = np.random.beta(2, 5) * (1 - feat_idx / dim)
                
                all_features.append(feature_name)
                all_importance.append(importance)
        
        # Sort by importance
        importance_data = sorted(zip(all_features, all_importance), key=lambda x: x[1], reverse=True)
        features, importance = zip(*importance_data[:15])  # Top 15 features
        
        # Create the plot
        plt.figure(figsize=(12, 8))
        colors = []
        for feat in features:
            if 'Table_1' in feat:
                colors.append('skyblue')
            elif 'Table_2' in feat:
                colors.append('lightgreen')
            else:
                colors.append('lightcoral')
        
        bars = plt.barh(range(len(features)), importance, color=colors)
        plt.yticks(range(len(features)), features)
        plt.xlabel('Importance Score')
        plt.title('Top 15 Feature Importance (Simulated)')
        plt.grid(axis='x', alpha=0.3)
        
        # Add legend
        handles = [plt.Rectangle((0,0),1,1, color='skyblue', label='Table 1'),
                  plt.Rectangle((0,0),1,1, color='lightgreen', label='Table 2'),
                  plt.Rectangle((0,0),1,1, color='lightcoral', label='Table 3')]
        plt.legend(handles=handles, loc='lower right')
        
        plt.tight_layout()
        plt.show()
        
        return list(zip(features, importance))
    
    # Create the visualizations
    if 'matplotlib' in sys.modules:
        arch_fig = plot_architecture_diagram()
        plot_data_quality_heatmap()
        feature_importance = create_feature_importance_plot()
    else:
        print("⚠️  Matplotlib not available for visualizations")

# %%
# Run advanced visualizations
create_advanced_visualizations()

# %% [markdown]
# # 🔧 Section 11: Troubleshooting & FAQ

# %%
def create_troubleshooting_guide():
    """Create a comprehensive troubleshooting guide."""
    print("\n" + "="*60)
    print("🔧 TROUBLESHOOTING GUIDE")
    print("="*60)
    
    problems_and_solutions = {
        "🚨 Training Errors": [
            {
                "problem": "CUDA out of memory",
                "solution": "Reduce batch_size in config, use smaller embed_dim, or train on CPU",
                "example": "training: { batch_size: 16 }  # Instead of 64"
            },
            {
                "problem": "Model convergence issues",
                "solution": "Lower learning rate, increase epochs, or reduce model complexity",
                "example": "optimizer: { name: adam, lr: 1e-4 }  # Instead of 1e-3"
            },
            {
                "problem": "Validation loss not improving",
                "solution": "Check for data leakage, reduce overfitting, or increase dataset size",
                "example": "Add dropout, reduce refinement_iterations, or use early stopping"
            }
        ],
        
        "🗂️  Data Issues": [
            {
                "problem": "Primary key alignment fails",
                "solution": "Ensure all datasets have the same primary key column with matching values",
                "example": "All CSVs must have 'customer_id' column with identical IDs"
            },
            {
                "problem": "Missing values causing errors", 
                "solution": "Handle missing values before training or configure proper imputation",
                "example": "df.fillna(df.mean()) or use more sophisticated imputation"
            },
            {
                "problem": "Inconsistent data types",
                "solution": "Ensure numerical features are properly typed and categorical features encoded",
                "example": "df['numeric_col'] = pd.to_numeric(df['numeric_col'], errors='coerce')"
            }
        ],
        
        "⚙️  Configuration Problems": [
            {
                "problem": "YAML parsing errors",
                "solution": "Check indentation, quotes, and YAML syntax",
                "example": "Use spaces (not tabs) for indentation, quote string values"
            },
            {
                "problem": "Model architecture mismatch",
                "solution": "Ensure input_dims match your actual data dimensions",
                "example": "Count features correctly after excluding primary key and target"
            },
            {
                "problem": "Resource constraints",
                "solution": "Scale down model size for local development",
                "example": "Use embed_dim: 32, refinement_iterations: 2 for testing"
            }
        ]
    }
    
    for category, issues in problems_and_solutions.items():
        print(f"\n{category}")
        print("-" * 40)
        
        for i, issue in enumerate(issues, 1):
            print(f"\n{i}. ❓ Problem: {issue['problem']}")
            print(f"   💡 Solution: {issue['solution']}")
            print(f"   📝 Example: {issue['example']}")

# %%
def create_faq_section():
    """Create a frequently asked questions section."""
    print("\n" + "="*60)
    print("❓ FREQUENTLY ASKED QUESTIONS")
    print("="*60)
    
    faqs = [
        {
            "q": "How does NexusFlow differ from traditional ML approaches?",
            "a": "NexusFlow processes multiple tables simultaneously without flattening, using specialized transformers that communicate via cross-attention. This preserves relationships between tables and captures complex multi-hop dependencies."
        },
        {
            "q": "When should I use NexusFlow vs. standard approaches?",
            "a": "Use NexusFlow when you have multiple related tables, complex relationships between entities, or when traditional feature engineering becomes too complex/lossy."
        },
        {
            "q": "How do I choose the right architecture parameters?",
            "a": "Start with embed_dim=64 and refinement_iterations=3. Increase embed_dim for more complex data, increase refinement_iterations for stronger table interactions. Monitor validation performance."
        },
        {
            "q": "Can I use different encoder types for different tables?",
            "a": "Yes! Set transformer_type to 'standard', 'text', or 'timeseries' in your dataset configuration. Each table can have its own specialized encoder."
        },
        {
            "q": "How much data do I need for good results?",
            "a": "Generally 1000+ aligned records minimum. More complex architectures need more data. The quality of relationships between tables is often more important than raw size."
        },
        {
            "q": "Is NexusFlow suitable for production use?",
            "a": "Yes, but ensure proper testing, monitoring, and MLOps practices. Start with smaller models in production and scale up based on performance requirements."
        },
        {
            "q": "How do I interpret the model's predictions?",
            "a": "Use the visualize_flow() method to understand information flow between tables. Feature importance analysis and attention visualization help explain predictions."
        },
        {
            "q": "Can I add new tables to an existing model?",
            "a": "Currently, you need to retrain with the new architecture. Future versions may support incremental table addition with transfer learning."
        }
    ]
    
    for i, faq in enumerate(faqs, 1):
        print(f"\n{i}. ❓ {faq['q']}")
        print(f"   💬 {faq['a']}")

# %%
def create_performance_optimization_tips():
    """Provide performance optimization tips."""
    print("\n" + "="*60)
    print("⚡ PERFORMANCE OPTIMIZATION TIPS")
    print("="*60)
    
    optimization_categories = {
        "🚀 Training Speed": [
            "Use GPU acceleration (CUDA) when available",
            "Optimize batch_size for your hardware (try 32, 64, 128)",
            "Use smaller embed_dim during development (32-64)",
            "Reduce refinement_iterations for faster prototyping (1-2)",
            "Use mixed precision training for larger models",
            "Profile your code to identify bottlenecks"
        ],
        
        "💾 Memory Usage": [
            "Reduce batch_size if getting OOM errors",
            "Use gradient accumulation for effective larger batches",
            "Clear unnecessary variables and use torch.cuda.empty_cache()",
            "Process data in chunks if datasets are very large",
            "Use appropriate data types (float32 instead of float64)",
            "Monitor memory usage throughout training"
        ],
        
        "🎯 Model Quality": [
            "Start with synthetic data to validate architecture",
            "Use cross-validation for robust evaluation",
            "Implement early stopping to prevent overfitting",
            "Experiment with different learning rates (1e-4 to 1e-2)",
            "Try different optimizers (Adam, AdamW, SGD)",
            "Use learning rate scheduling for better convergence"
        ],
        
        "📊 Data Efficiency": [
            "Ensure high-quality primary key alignment",
            "Remove highly correlated or low-variance features",
            "Use appropriate feature scaling within each table",
            "Handle missing values strategically (not just fillna(0))",
            "Consider feature selection techniques",
            "Validate data quality before training"
        ]
    }
    
    for category, tips in optimization_categories.items():
        print(f"\n{category}")
        print("-" * 35)
        for tip in tips:
            print(f"   • {tip}")

# %%
# Run troubleshooting sections
create_troubleshooting_guide()
create_faq_section()
create_performance_optimization_tips()

# %% [markdown]
# # 🎉 Section 12: Final Wrap-up & Resources

# %%
def create_final_summary():
    """Create the final comprehensive summary."""
    print("\n" + "="*80)
    print("🎉 NEXUSFLOW TUTORIAL COMPLETE!")
    print("="*80)
    
    print("\n🏆 What You've Mastered:")
    mastery_areas = [
        "✅ Project structure and initialization",
        "✅ Configuration management and best practices", 
        "✅ Multi-table data preparation and alignment",
        "✅ Model training with both synthetic and real data",
        "✅ Architecture understanding and parameter tuning",
        "✅ Model evaluation and performance analysis",
        "✅ Inference and production deployment patterns",
        "✅ Troubleshooting and optimization techniques",
        "✅ Advanced visualization and model introspection",
        "✅ MLOps integration and experiment tracking"
    ]
    
    for area in mastery_areas:
        print(f"   {area}")
    
    print(f"\n🗂️  Files Created in This Tutorial:")
    created_files = [
        "📁 nexusflow_demo/ - Sample project structure",
        "📄 datasets/customers.csv - Sample customer data",
        "📄 datasets/transactions.csv - Sample transaction data", 
        "📄 datasets/support.csv - Sample support data",
        "🧠 *.nxf - Trained model artifacts",
        "📈 results/metrics.json - Training metrics log",
        "📋 experiments_log.json - Experiment tracking data"
    ]
    
    for file_info in created_files:
        print(f"   {file_info}")
    
    print(f"\n🚀 Ready for Production:")
    production_checklist = [
        "🔧 CLI commands: nexusflow init, train, validate",
        "🏗️  Architecture design principles and trade-offs",
        "📊 Data quality assessment and improvement strategies",
        "🎯 Model evaluation and performance monitoring",
        "🔍 Debugging and troubleshooting techniques",
        "⚡ Performance optimization for different scenarios",
        "🛡️  Production deployment considerations and best practices"
    ]
    
    for item in production_checklist:
        print(f"   {item}")
    
    print(f"\n🌟 Key Takeaways:")
    takeaways = [
        "NexusFlow excels at learning from multiple related tables without data flattening",
        "Cross-attention mechanisms enable sophisticated inter-table relationships",
        "Start simple (synthetic data, small models) then scale up systematically",
        "Configuration-driven approach enables reproducible experiments",
        "Built-in MLOps integration supports production deployment",
        "Visualization capabilities provide model interpretability",
        "Community-focused design encourages contribution and extension"
    ]
    
    for takeaway in takeaways:
        print(f"   💡 {takeaway}")
    
    print(f"\n🔗 Connect with the Community:")
    community_info = [
        "📖 Documentation: Explore the full project documentation",
        "🐛 Issues: Report bugs or request features on GitHub",
        "💬 Discussions: Join the community discussions",
        "🤝 Contributing: Submit pull requests and improvements",
        "📧 Contact: Reach out to the development team",
        "🎓 Learning: Share your success stories and use cases"
    ]
    
    for info in community_info:
        print(f"   {info}")
    
    print("\n" + "="*80)
    print("Thank you for exploring NexusFlow! 🚀")
    print("Build amazing multi-transformer tabular ecosystems! 🌟")
    print("="*80)

# %%
# Final summary
create_final_summary()

# %% [markdown]
# Save this notebook's state for future reference
